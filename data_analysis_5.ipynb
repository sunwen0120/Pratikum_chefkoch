# %%
# the library used
import numpy as np
import pandas as pd
import pysubgroup as ps
import re
from sklearn.feature_extraction import DictVectorizer
import time
import ast
import string 
import imblearn
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Helper Function

# %%
def tags_preprocess(tags):
    """
    input: tag string
    output: list of individual tags in the given tag string
    function: preprocess a single tag string 
    """
    #tags = tags.replace("'","")
    #tags = tags.replace(" ","")
    #tags = tags.replace("[","")
    #tags = tags.replace("]","")
    tags = str(tags)
    tags = tags.split(" ")
    tags = [x.lower() for x in tags]
    return tags

# %%
def ingredients_preprocess(df):
    """
    input: dataframe
    output: list of distinct ingredient list
    function: preprocess the ingredient columns and return a list of distinct ingredients
    """
    distinct_ingredients = []
    dataframe = df
    
    for i in range(len(dataframe)):
        ingredients = dataframe.iloc[i]['ingredient']
        
        r = re.compile('[A-Z]{1}[a-zA-Z]+')
        ingredients = str(ingredients)
        #ingredients = ''.join(i for i in ingredients if not i.isdigit())
        ingredients = ingredients.replace("'","")
        #ingredients = ingredients.replace(" ","")
        ingredients = ingredients.replace("[","")
        ingredients = ingredients.replace("]","")
        # remove text inside parentheses
        ingredients = re.sub(r'\([^())]*\)',"", ingredients)
        ingredients = ingredients.split(" ")
        ingredients = list(filter(r.match, ingredients))
        ingredients = [x.lower() for x in ingredients]
        distinct_ingredients += ingredients
        dataframe.at[i, 'ingredient'] = ingredients
        #dataframe.set_value(i, 'ingredient', ingredients)
        
    return [list(set(distinct_ingredients)),dataframe]

# %%
def get_recipe_countries(countries, data):
    """
    input: list of countries, dataframe
    output: selected dataframe whose recipes is from these countries
    function: select the rows in dataframe whose "tag" value contain one country tag
    """
    # add a new column class 
    drop_index = []
    for i in range(len(data)):
        tags = data.loc[i]["tags"]
        tags = tags_preprocess(tags)
        
        country_same =[l for l in countries if l in tags]
            
        if len(country_same) == 1:
            data.at[i, 'label'] = country_same[0]
        if len(country_same) == 0:
            drop_index.append(i)
        if len(country_same) > 1:
            drop_index.append(i)
            #data.at[i, 'label'] = 'overlap'
            
    # drop the columns which has no season tags
    data = data.drop(data.index[drop_index])
    return data

# %%
def convert_to_dict(arr):
    """
    Helper function to convect an array of ingredients to a dictionary
    """
    d={}
    for a in arr:
        d[a]=1
    return d

# %%
# extract comment user dataset from original dataset
def extract_com_user(data):
    """
    input: dataframe
    output: a new dataframe with all the comment user information
    function: spilt the dictionary of the column 'comment user' in original dataset
    """
    df_com = pd.DataFrame()
    for index, item in data['comment_user'].iteritems():
        if (item != '[]'):
            if (item != 'no comment'):
                array = ast.literal_eval(item)
                df_array = pd.DataFrame(array)
                df_array['recipe_id'] = index
                df_com = pd.concat([df_com,df_array])
    return df_com

# %%
def sub_cat_in_com(data):
    """
    input: dataframe
    output: a new dataframe with multi colunms
    function: add one subcategory of recipes to comment user dataset 
    """    
    punct = set(string.punctuation) 
    list_sub_cat = []
    
    df_com2 = pd.DataFrame()
    for index, item in data['calorie_value'].iteritems(): 
        if (item != None):
            list_sub = list(item)
            list_sub = ''.join(x for x in list_sub if x not in punct)
            list_sub_cat.append(list_sub)
    df_sub_cat = pd.DataFrame(list_sub_cat)
    df_sub_cat['calorie_value'] = df_sub_cat
    
    df_sub_cat['recipe_id'] = data['calorie_value'].index     
    df_com2 = pd.concat([df_com2,df_sub_cat])
    return df_com2

# %%
def add_recipe_info(data):
    """
    input: dataframe
    output: a new dataframe with multi colunms
    function: add one subcategory of recipes to comment user dataset 
    """    
    punct = set(string.punctuation) 
    # add recipe name in comment users data
    list_recipe_name = []
    df_recipe = pd.DataFrame()
    for index, item in data['recipe_name'].iteritems(): 
        if (item != None):
            list_name = list(item)
            list_name = ''.join(x for x in list_name if x not in punct)
            list_recipe_name.append(list_name)

    df_name = pd.DataFrame(list_recipe_name)
    df_name['recipe_id'] = data['recipe_name'].index 
    df_name = df_name.set_index(["recipe_id"])
    df_name
    df_recipe['recipe_name'] = df_name[0]

    # add recipe difficulty in comment users data
    list_recipe_diff = []
    df_recipe_diff = pd.DataFrame()
    for index, item in data['difficulty'].iteritems(): 
        if (item != None):
            list_diff = list(item)      
            list_diff = ''.join(x for x in list_diff if x not in punct)   
            list_recipe_diff.append(list_diff)

    df_diff = pd.DataFrame(list_recipe_diff)
    df_diff['recipe_id'] = data['difficulty'].index 
    df_diff = df_diff.set_index(["recipe_id"])
    df_recipe['difficulty'] = df_diff[0]

    # add recipe preparation_time in comment users data
    list_recipe_pre = []
    df_recipe_pre = pd.DataFrame()
    for index, item in data['preparation_time'].iteritems(): 
        if (item != None):
            list_pre = list(item)

            list_pre = ''.join(x for x in list_pre if x not in punct)

            list_recipe_pre.append(list_pre)

    df_pre = pd.DataFrame(list_recipe_pre)
    df_pre['recipe_id'] = data['preparation_time'].index 
    df_pre = df_pre.set_index(["recipe_id"])
    df_recipe['preparation_time'] = df_pre[0]

    # add recipe tags in comment users data
    list_recipe_tags = []
    df_recipe_tags = pd.DataFrame()
    for index, item in data['tags'].iteritems(): 
        if (item != None):
            list_tags = list(item)      
            list_tags = ''.join(x for x in list_tags if x not in punct)   
            list_recipe_tags.append(list_tags)


    df_tags = pd.DataFrame(list_recipe_tags)
    df_tags['recipe_id'] = data['tags'].index 
    df_tags = df_tags.set_index(["recipe_id"])
    df_recipe['tags'] = df_tags[0]

    # add recipe ingredient in comment users data
    list_recipe_ingredient = []
    df_recipe_ingredient = pd.DataFrame()
    for index, item in data['ingredient'].iteritems(): 
        if (item != None):
            list_ingredient = list(item) 
            list_ingredient = ''.join(x for x in list_ingredient if x not in punct)
            list_recipe_ingredient.append(list_ingredient)

    df_recipe_ingredient = pd.DataFrame(list_recipe_ingredient)
    df_recipe_ingredient['recipe_id'] = data['ingredient'].index 
    df_recipe_ingredient = df_recipe_ingredient.set_index(["recipe_id"])
    df_recipe['ingredient'] = df_recipe_ingredient[0]
    return df_recipe

# %%
def age_group(age):   
    """
    input: age value
    output: group description
    function: divide age value uinto 5 groups 
    """   
    bucket = None
    age = int(age)    
    if age <= 30:
        bucket = '<30 Jahre'     
    if age in range(30, 46):
        bucket = '30-45 Jahre'
    if age in range(45, 61):
        bucket = '45-60 Jahre'
    if age >= 61:
        bucket = '60+ Jahre'
    return bucket

# %%
def calorie_level(calorie):   
    """
    input: calorie value
    output: group description
    function: divide calorie value into 3 groups 
    """   
    bucket = None
    calorie = int(calorie)    
    if calorie <= 300:
        bucket = 'low_calorie'    
    if calorie in range(300, 500):
        bucket = 'medium_calorie'        
    if calorie >= 500:
        bucket = 'high_calorie'      
    return bucket

# %%
def remove_None(data, name):
    """
    Helper function to remove None value in one column
    """ 
    y = data[data[name] == 'None']
    index_n = y.index.tolist()
    data = data.drop(index = index_n)
    return data

# %%
def add_target(data, calorie_level):
    df_sub_group[country] = df_dum_car[calorie_level]
    return df_sub_group

# %%
def pre_time_group(pre_time):   
    pre_time = int(pre_time)    
    if pre_time <= 20:
        bucket = '<20 Min'    
    if pre_time in range(20, 31):
        bucket = '20-30 Min'                
    if pre_time >= 31:
        bucket = '30+ Min'
    return bucket

# %% [markdown]
# ## Subgroup Discovery
#
# In this section we will use subgroup discovery to explore the association rules between attributes
#
# - why we choose subgroup discovery?
#
# because we find out that subgroup discovery is quite powerful compared to other data mining techniques. As long as we set differnt target with different search space, we can use use subgroup discovery technique to dig many interesting patterns that we want to explore from the dataset.

# %%
# read the data
# data = pd.read_csv("all_data.csv")
data = pd.read_csv("/Users/xujingjing/Desktop/2020 Sommer/praktikum/Data/all_data.csv")

# %%
# extract the recipe id from recipe urls
list_cat_no = []
i = 0
for item in data['recipe_url']:
    list_cat_no.append(item.split('/')[4])
    
# add one column "recipe_id" into the dataset and set it as the index of dataset
data['recipe_id'] = list_cat_no
data = data.set_index(["recipe_id"])

# %% [markdown]
# ## Association rules between comment user information and recipe attributes

# %% [markdown]
# ### associations with "calorie" and comment user information
#
# since the job has more than half non values, so here we only explore the the association between  marriage_status, gender, and age with recipe calorie

# %%
# extract the numerical value string in the column calorie 
pat = r"([-+]?\d*\.\d+|\d+)"
data["calorie_value"] = data["calorie"].str.extract(pat, flags=0, expand=True)

# drop all rows with nan value in both columns comment_user and calorie_value
data_com = data.dropna(subset=["comment_user",'calorie_value'])
len(data_com)
# Out:
# 19058

# %%
# expand the corresponding recipe data for each comment_user
df_com_1 = extract_com_user(data_com)
df_com_2 = sub_cat_in_com(data_com)
df_com_3 = add_recipe_info(data_com)
df_com_new = df_com_1.merge(df_com_2, on='recipe_id', how='left')
df_com_new = df_com_new.merge(df_com_3, on='recipe_id', how='left')

df_com_new = df_com_new[['recipe_id','recipe_name','tags','difficulty','preparation_time','ingredient','name','rating','sex','age','marriage_status','comment_time','calorie_value']]
df_com_new = df_com_new.set_index(["recipe_id"])

# %%
# remove none value in the whole data set 
df_com_no_none = df_com_new.mask(df_com_new.astype(object).eq('None')).dropna()
df_com_no_none = df_com_no_none.reset_index()

# %%
# calculate and add calorie level , preparation time and age group columns in the comment user information
df_com_no_none["pretime_value"] = df_com_no_none["preparation_time"].str.extract(pat, flags=0, expand=True)
df_com_no_none['pre_time_group'] = df_com_no_none['pretime_value'].apply(pre_time_group)

df_com_no_none['calorie_level'] = df_com_no_none['calorie_value'].apply(calorie_level)
df_dum_calorie = pd.get_dummies(df_com_no_none['calorie_level'])

df_com_no_none["age_value"] = df_com_no_none["age"].str.extract(pat, flags=0, expand=True)
df_com_no_none['age_group'] = df_com_no_none['age_value'].apply(age_group)

df_com_dum_calorie = df_com_no_none.join(df_dum_calorie, how='left')

# %%
df_com_dum_calorie['age_group'].value_counts()
# Out:
# 30-45 Jahre    43292
# 45-60 Jahre    26865
# 60+ Jahre       7498
# <30 Jahre       7418
# Name: age_group, dtype: int64

# %%
df_com_dum_calorie['sex'].value_counts()
# Out:
# weiblich    72689
# männlich    12384
# Name: sex, dtype: int64

# %%
df_com_dum_calorie['calorie_level'].value_counts()
# Out:
# high_calorie      46732
# medium_calorie    19498
# low_calorie       18843
# Name: calorie_level, dtype: int64

# %%
df_com_dum_calorie['marriage_status'].value_counts()
# Out:
# Verheiratet    46127
# Vergeben       28338
# Single          8703
# Verwitwet       1470
# Geschieden       435
# Name: marriage_status, dtype: int64

# %% [markdown]
# #### Subgroup discovery before up/down sampling
#
# the target is calorie and features are the sex,age,marriage status of comment users

# %%
data = df_com_dum_calorie[['sex', 'age_group', 'high_calorie', 'low_calorie', 'medium_calorie','marriage_status']]
print("the length of dataset:", len(data))
target = ps.BinaryTarget('low_calorie', True)
searchspace = ps.create_selectors(data, ignore=['high_calorie', 'low_calorie', 'medium_calorie'])
task = ps.SubgroupDiscoveryTask (
    data, 
    target, 
    searchspace, 
    result_set_size=5, 
    depth=2, 
    qf=ps.WRAccQF())
result = ps.BeamSearch().execute(task)
pd.set_option('max_colwidth',100)
print(result.to_dataframe())
# Out:
# the length of dataset: 85073
#     quality                                   description
# 0  0.002450    age_group=='60+ Jahre' AND sex=='weiblich'
# 1  0.002306  age_group=='45-60 Jahre' AND sex=='weiblich'
# 2  0.002248                        age_group=='60+ Jahre'
# 3  0.002194                      age_group=='45-60 Jahre'
# 4  0.002010                               sex=='weiblich'

# %% [markdown]
# #### Deal with imbalanced data
#
# "high_calorie": "medium_calorie": "low_calorie" ratio is around 2.5:1:1, the data is quite imblanced with regard to the calorie level, we want to try to resample the dataset to help improve the data quality. We want to see if we can improve the quality of subgroup discovery
#
# - upsampling: upsample "medium_calorie" and "low_calorie" samples to make them equal to the number of "high_calorie"

# %%
df_sampling = df_com_dum_calorie[['rating','sex','age_group','marriage_status','calorie_level','pre_time_group','difficulty','tags','ingredient']]

# %%
# oversampling
# Separate input features and target
y = df_sampling['calorie_level']
X = df_sampling.drop('calorie_level', axis=1)

# setting up testing and training sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)

# concatenate our training data back together
# X = pd.concat([X_train, y_train], axis=1)

# separate minority and majority classes
high_calorie = df_sampling[df_sampling['calorie_level'] == 'high_calorie']
low_calorie = df_sampling[df_sampling['calorie_level'] == 'low_calorie']
medium_calorie = df_sampling[df_sampling['calorie_level'] == 'medium_calorie']


# upsample minority
low_upsampled = resample(low_calorie,
                          replace=True, # sample with replacement
                          n_samples=len(high_calorie), # match number in majority class
                          random_state=27) # reproducible results

medium_upsampled = resample(medium_calorie,
                          replace=True,
                          n_samples=len(high_calorie), 
                          random_state=27) 


# combine majority and upsampled minority
upsampled = pd.concat([high_calorie, low_upsampled])
upsampled = pd.concat([upsampled, medium_upsampled])
upsampled.reset_index(inplace = True)
print("After upsampling:")
upsampled['calorie_level'].value_counts()
# upsampled.head()
# Out:
# After upsampling:
# high_calorie      46732
# medium_calorie    46732
# low_calorie       46732
# Name: calorie_level, dtype: int64

# %%
# add the dummyset into the upsampled dataset
upsampled_dum = pd.get_dummies(upsampled['calorie_level'])
upsampled_dum.reset_index(inplace = True)
upsampled_dum = upsampled_dum.drop('index', axis=1)

# prepare for the binary target columns
# upsampled = upsampled.drop('index', axis=1)
upsampled_new = upsampled.join(upsampled_dum, how='left')
# upsampled_new = upsampled_new.drop('calorie_level',1)
# upsampled_new['sex'].value_counts()

# %%
data = upsampled_new[['sex', 'age_group', 'high_calorie', 'low_calorie', 'medium_calorie','marriage_status']]
target = ps.BinaryTarget('medium_calorie', True)
searchspace = ps.create_selectors(data, ignore=['high_calorie', 'low_calorie', 'medium_calorie'])
task = ps.SubgroupDiscoveryTask (
    data, 
    target, 
    searchspace, 
    result_set_size=5, 
    depth=2, 
    qf=ps.WRAccQF())
result = ps.BeamSearch().execute(task)
pd.set_option('max_colwidth',100)
print(result.to_dataframe())
# Out:
#     quality                                                  description
# 0  0.001933                                              sex=='männlich'
# 1  0.001555                                     age_group=='45-60 Jahre'
# 2  0.001448  age_group=='45-60 Jahre' AND marriage_status=='Verheiratet'
# 3  0.001431           marriage_status=='Verheiratet' AND sex=='männlich'
# 4  0.000965                 age_group=='45-60 Jahre' AND sex=='männlich'

# %% [markdown]
# - undersampling : downsample "high-calorie" data samples to make it equal to the number of "low_calorie" or "medium_calorie"

# %%
# downsample majority
high_downsampled = resample(high_calorie,
                                replace = False, # sample without replacement
                                n_samples = len(low_calorie), # match minority n
                                random_state = 27) # reproducible results

medium_downsampled = resample(medium_calorie,
                                replace = False,
                                n_samples = len(low_calorie),
                                random_state = 27)

# combine minority and downsampled majority
downsampled = pd.concat([high_downsampled, low_calorie])
downsampled = pd.concat([downsampled, medium_downsampled])

# add the dummyset into the downsampled dataset
downsampled_dum = pd.get_dummies(downsampled['calorie_level'])
# downsampled_dum.reset_index(inplace = True)
# downsampled.reset_index(inplace = True)
downsampled_new = downsampled.join(downsampled_dum, how='left')
print("After downsampling:")
downsampled_new['calorie_level'].value_counts()
# Out:
# After downsampling:
# high_calorie      18843
# medium_calorie    18843
# low_calorie       18843
# Name: calorie_level, dtype: int64

# %%
data = downsampled_new[['sex', 'age_group', 'high_calorie', 'low_calorie', 'medium_calorie','marriage_status']]
target = ps.BinaryTarget('medium_calorie', True)
searchspace = ps.create_selectors(data, ignore=['high_calorie', 'low_calorie', 'medium_calorie'])
task = ps.SubgroupDiscoveryTask (
    data, 
    target, 
    searchspace, 
    result_set_size=5, 
    depth=2, 
    qf=ps.WRAccQF())
result = ps.BeamSearch().execute(task)
pd.set_option('max_colwidth',100)
print(result.to_dataframe())
# Out:
#     quality                                                  description
# 0  0.002353                                              sex=='männlich'
# 1  0.001238                                     age_group=='45-60 Jahre'
# 2  0.001150  age_group=='45-60 Jahre' AND marriage_status=='Verheiratet'
# 3  0.001067              marriage_status=='Vergeben' AND sex=='männlich'
# 4  0.001056           marriage_status=='Verheiratet' AND sex=='männlich'

# %% [markdown]
# - Explore the male and female comment users separately

# %%
# df_male = df_com_dum_calorie[df_com_dum_calorie['sex'] == 'männlich']
# data = df_male[['age_group', 'high_calorie', 'low_calorie', 'medium_calorie','marriage_status']]
# target = ps.BinaryTarget('low_calorie', True)
# searchspace = ps.create_selectors(data, ignore=['high_calorie', 'low_calorie', 'medium_calorie'])
# task = ps.SubgroupDiscoveryTask (
#     data, 
#     target, 
#     searchspace, 
#     result_set_size=5, 
#     depth=2, 
#     qf=ps.WRAccQF())
# result = ps.BeamSearch().execute(task)
# pd.set_option('max_colwidth',100)
# print(result.to_dataframe())

# %%
# df_female = df_com_dum_calorie[df_com_dum_calorie['sex'] == 'weiblich']
# data = df_female[['age_group', 'high_calorie', 'low_calorie', 'medium_calorie','marriage_status']]
# target = ps.BinaryTarget('low_calorie', True)
# searchspace = ps.create_selectors(data, ignore=['high_calorie', 'low_calorie', 'medium_calorie'])
# task = ps.SubgroupDiscoveryTask (
#     data, 
#     target, 
#     searchspace, 
#     result_set_size=5, 
#     depth=2, 
#     qf=ps.WRAccQF())
# result = ps.BeamSearch().execute(task)
# pd.set_option('max_colwidth',100)
# print(result.to_dataframe())

# %% [markdown]
# - the subgroup 30-45 years-old female who are married or in relationship seem to prefer the "high-calorie" recipes
# - the subgroup married 45-60 years-old male or the erdly who are married seem to prefer the "medium-calorie" recipes
# - the subgroup over 60 years old female or widowed female seem to prefer the "low-calorie" recipes
#
# then our next step is to discover why differnt calorie-level is preferred by these particular groups

# %% [markdown]
# ### Existing problems
# - Here we remove all rows which have nan, does it make sense to use other fill nan methods?
# - After resampling the quality is still low, how can we then to improve the quality?
# - we have downsampled to deal with the imbalance problem in target "calorie-level", but "sex", "age-group", "marriage_status" are still very imbalanced, should we also deal with that?

# %% [markdown]
# ## Discover why differnt calorie-level is preferred by these particular groups

# %% [markdown]
# #### The target is calorie level and features is the preparation time and difficulty of recipes.

# %%
df_com_dum_calorie['pre_time_group'].value_counts()
# Out:
# 20-30 Min    45209
# <20 Min      28338
# 30+ Min      11526
# Name: pre_time_group, dtype: int64

# %%
data = downsampled_new[['high_calorie', 'low_calorie', 'medium_calorie','pre_time_group','difficulty']]
target = ps.BinaryTarget('medium_calorie', True)
searchspace = ps.create_selectors(data, ignore=['high_calorie', 'low_calorie', 'medium_calorie'])
task = ps.SubgroupDiscoveryTask (
    data, 
    target, 
    searchspace, 
    result_set_size=5, 
    depth=2, 
    qf=ps.WRAccQF())
result = ps.BeamSearch().execute(task)
pd.set_option('max_colwidth',100)
print(result.to_dataframe())
# Out:
#     quality                                           description
# 0  0.014641                                  difficulty=='normal'
# 1  0.013344  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.007701                           pre_time_group=='20-30 Min'
# 3  0.002253    difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.001285                                 difficulty=='pfiffig'

# %% [markdown]
# conclusion:
#
# - 'high_calorie' recipes are high possibly with normal difficulty, takes more than 20 mininutes to cook
# - 'low_calorie' recipes are high possibly with simple difficulty, takes less than 20 mininutes to cook
# - 'medium_calorie' recipes are high possibly with normal or pfiffig difficulty, takes less than 20-30 mininutes to cook

# %% [markdown]
# - the target is the attributes of users and features is the preparation time and difficulty of recipes.

# %%
new_data = downsampled_new[['sex','age_group','marriage_status','pre_time_group','difficulty','calorie_level']]

#  set the target value by combining 'sex', 'age_group', 'marriage_status'
new_data['combine'] = new_data[['sex', 'age_group', 'marriage_status']].values.tolist()
new_data['combine'] = new_data['combine'].astype(str)

# one hot embedding of target value
combine_dum = pd.get_dummies(new_data['combine'])
new_data = new_data.join(combine_dum, how='left')
# combine_dum
# new_data.head()
# Out:
# /Users/xujingjing/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/xujingjing/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# discover the relationship bewteen all the comment user groups and the preparation time and difficulty of recipes

data = new_data[['pre_time_group','difficulty']]
i =0
for col in combine_dum:
    column_name = col
    column_name = str(column_name)
    data[column_name] = new_data[column_name]

    target = ps.BinaryTarget(column_name, True)
    searchspace = ps.create_selectors(data, ignore=[column_name])
    task = ps.SubgroupDiscoveryTask (
        data, 
        target, 
        searchspace, 
        result_set_size=5, 
        depth=2, 
        qf=ps.WRAccQF())
    result = ps.BeamSearch().execute(task)
    pd.set_option('max_colwidth',100)
    result = result.to_dataframe()
    result = result.rename(columns={'description':column_name})
    data = data.drop(column_name,1)
    i = i+1
    print('----------------------------------------------------------------------')
    print("number of target combination is:", i)
    print(result)
# Out:
# /Users/xujingjing/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ----------------------------------------------------------------------
# number of target combination is: 1
#     quality             ['männlich', '30-45 Jahre', 'Geschieden']
# 0  0.000042  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 1  0.000026                                  difficulty=='normal'
# 2  0.000023                           pre_time_group=='20-30 Min'
# 3  0.000000                                               Dataset
# ----------------------------------------------------------------------
# number of target combination is: 2
#     quality                 ['männlich', '30-45 Jahre', 'Single']
# 0  0.000351                             pre_time_group=='<20 Min'
# 1  0.000297    difficulty=='simpel' AND pre_time_group=='<20 Min'
# 2  0.000136                                  difficulty=='normal'
# 3  0.000115  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 4  0.000054    difficulty=='normal' AND pre_time_group=='<20 Min'
# ----------------------------------------------------------------------
# number of target combination is: 3
#     quality             ['männlich', '30-45 Jahre', 'Vergeben']
# 0  0.000337                           pre_time_group=='30+ Min'
# 1  0.000276  difficulty=='normal' AND pre_time_group=='30+ Min'
# 2  0.000158  difficulty=='normal' AND pre_time_group=='<20 Min'
# 3  0.000120                                difficulty=='normal'
# 4  0.000112  difficulty=='simpel' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 4
#     quality            ['männlich', '30-45 Jahre', 'Verheiratet']
# 0  0.000335                             pre_time_group=='<20 Min'
# 1  0.000249    difficulty=='simpel' AND pre_time_group=='<20 Min'
# 2  0.000218                                  difficulty=='normal'
# 3  0.000153                             pre_time_group=='30+ Min'
# 4  0.000143  difficulty=='normal' AND pre_time_group=='20-30 Min'
# ----------------------------------------------------------------------
# number of target combination is: 5
#         quality             ['männlich', '45-60 Jahre', 'Geschieden']
# 0  9.904279e-05  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 1  9.602921e-05                           pre_time_group=='20-30 Min'
# 2  3.223693e-05                                  difficulty=='simpel'
# 3  1.689862e-08  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 4  0.000000e+00                                               Dataset
# ----------------------------------------------------------------------
# number of target combination is: 6
#     quality                 ['männlich', '45-60 Jahre', 'Single']
# 0  0.000277                           pre_time_group=='20-30 Min'
# 1  0.000274                                  difficulty=='normal'
# 2  0.000202    difficulty=='normal' AND pre_time_group=='<20 Min'
# 3  0.000150  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 4  0.000133  difficulty=='normal' AND pre_time_group=='20-30 Min'
# ----------------------------------------------------------------------
# number of target combination is: 7
#     quality             ['männlich', '45-60 Jahre', 'Vergeben']
# 0  0.000131  difficulty=='normal' AND pre_time_group=='30+ Min'
# 1  0.000119                           pre_time_group=='<20 Min'
# 2  0.000109                           pre_time_group=='30+ Min'
# 3  0.000086  difficulty=='simpel' AND pre_time_group=='<20 Min'
# 4  0.000073                                difficulty=='simpel'
# ----------------------------------------------------------------------
# number of target combination is: 8
#     quality            ['männlich', '45-60 Jahre', 'Verheiratet']
# 0  0.001669                                  difficulty=='normal'
# 1  0.000937  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.000743                             pre_time_group=='30+ Min'
# 3  0.000582                           pre_time_group=='20-30 Min'
# 4  0.000528    difficulty=='normal' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 9
#     quality            ['männlich', '45-60 Jahre', 'Verwitwet']
# 0  0.000017  difficulty=='simpel' AND pre_time_group=='<20 Min'
# 1  0.000008                           pre_time_group=='<20 Min'
# 2  0.000008  difficulty=='normal' AND pre_time_group=='30+ Min'
# 3  0.000003                           pre_time_group=='30+ Min'
# 4  0.000001                                difficulty=='simpel'
# ----------------------------------------------------------------------
# number of target combination is: 10
#     quality               ['männlich', '60+ Jahre', 'Geschieden']
# 0  0.000042                                  difficulty=='normal'
# 1  0.000024    difficulty=='normal' AND pre_time_group=='30+ Min'
# 2  0.000020  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 3  0.000009                           pre_time_group=='20-30 Min'
# 4  0.000001                             pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 11
#     quality                   ['männlich', '60+ Jahre', 'Single']
# 0  0.000313                                  difficulty=='normal'
# 1  0.000129                             pre_time_group=='30+ Min'
# 2  0.000112    difficulty=='normal' AND pre_time_group=='<20 Min'
# 3  0.000103  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 4  0.000098    difficulty=='normal' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 12
#     quality                 ['männlich', '60+ Jahre', 'Vergeben']
# 0  0.000289                                  difficulty=='normal'
# 1  0.000166  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.000105    difficulty=='normal' AND pre_time_group=='30+ Min'
# 3  0.000082                             pre_time_group=='<20 Min'
# 4  0.000072    difficulty=='simpel' AND pre_time_group=='<20 Min'
# ----------------------------------------------------------------------
# number of target combination is: 13
#     quality              ['männlich', '60+ Jahre', 'Verheiratet']
# 0  0.001087                                  difficulty=='normal'
# 1  0.000932                             pre_time_group=='30+ Min'
# 2  0.000708    difficulty=='normal' AND pre_time_group=='30+ Min'
# 3  0.000362  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 4  0.000165   difficulty=='pfiffig' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 14
#     quality                ['männlich', '60+ Jahre', 'Verwitwet']
# 0  0.000138                           pre_time_group=='20-30 Min'
# 1  0.000133  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.000104                                  difficulty=='normal'
# 3  0.000009  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 4  0.000006    difficulty=='normal' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 15
#     quality                 ['männlich', '<30 Jahre', 'Single']
# 0  0.000547  difficulty=='simpel' AND pre_time_group=='<20 Min'
# 1  0.000542                           pre_time_group=='<20 Min'
# 2  0.000328                                difficulty=='simpel'
# 3  0.000126  difficulty=='simpel' AND pre_time_group=='30+ Min'
# 4  0.000038                               difficulty=='pfiffig'
# ----------------------------------------------------------------------
# number of target combination is: 16
#     quality               ['männlich', '<30 Jahre', 'Vergeben']
# 0  0.000216                           pre_time_group=='<20 Min'
# 1  0.000140  difficulty=='simpel' AND pre_time_group=='<20 Min'
# 2  0.000089                           pre_time_group=='30+ Min'
# 3  0.000081  difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.000077  difficulty=='normal' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 17
#     quality              ['männlich', '<30 Jahre', 'Verheiratet']
# 0  0.000078                                  difficulty=='simpel'
# 1  0.000070  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 2  0.000046                           pre_time_group=='20-30 Min'
# 3  0.000020    difficulty=='simpel' AND pre_time_group=='30+ Min'
# 4  0.000000                                               Dataset
# ----------------------------------------------------------------------
# number of target combination is: 18
#     quality            ['weiblich', '30-45 Jahre', 'Geschieden']
# 0  0.000212   difficulty=='simpel' AND pre_time_group=='<20 Min'
# 1  0.000180                            pre_time_group=='<20 Min'
# 2  0.000162                                 difficulty=='simpel'
# 3  0.000052                                difficulty=='pfiffig'
# 4  0.000032  difficulty=='pfiffig' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 19
#     quality                ['weiblich', '30-45 Jahre', 'Single']
# 0  0.000152   difficulty=='simpel' AND pre_time_group=='30+ Min'
# 1  0.000134                            pre_time_group=='<20 Min'
# 2  0.000104                                difficulty=='pfiffig'
# 3  0.000085  difficulty=='pfiffig' AND pre_time_group=='<20 Min'
# 4  0.000069                            pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 20
#     quality                ['weiblich', '30-45 Jahre', 'Vergeben']
# 0  0.001707                                   difficulty=='simpel'
# 1  0.001570     difficulty=='simpel' AND pre_time_group=='<20 Min'
# 2  0.001248                              pre_time_group=='<20 Min'
# 3  0.000309   difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 4  0.000167  difficulty=='pfiffig' AND pre_time_group=='20-30 Min'
# ----------------------------------------------------------------------
# number of target combination is: 21
#     quality            ['weiblich', '30-45 Jahre', 'Verheiratet']
# 0  0.001652                           pre_time_group=='20-30 Min'
# 1  0.001486  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 2  0.000308    difficulty=='simpel' AND pre_time_group=='30+ Min'
# 3  0.000291                                 difficulty=='pfiffig'
# 4  0.000268                             pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 22
#     quality            ['weiblich', '30-45 Jahre', 'Verwitwet']
# 0  0.000017  difficulty=='normal' AND pre_time_group=='<20 Min'
# 1  0.000011                           pre_time_group=='<20 Min'
# 2  0.000010                                difficulty=='normal'
# 3  0.000000                                             Dataset
# ----------------------------------------------------------------------
# number of target combination is: 23
#     quality             ['weiblich', '45-60 Jahre', 'Geschieden']
# 0  0.000074                           pre_time_group=='20-30 Min'
# 1  0.000045  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.000033  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 3  0.000028    difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.000017   difficulty=='pfiffig' AND pre_time_group=='<20 Min'
# ----------------------------------------------------------------------
# number of target combination is: 24
#     quality                 ['weiblich', '45-60 Jahre', 'Single']
# 0  0.000756                             pre_time_group=='<20 Min'
# 1  0.000586                                  difficulty=='simpel'
# 2  0.000556    difficulty=='simpel' AND pre_time_group=='<20 Min'
# 3  0.000196    difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.000066  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# ----------------------------------------------------------------------
# number of target combination is: 25
#     quality               ['weiblich', '45-60 Jahre', 'Vergeben']
# 0  0.001147    difficulty=='simpel' AND pre_time_group=='<20 Min'
# 1  0.000883                                  difficulty=='simpel'
# 2  0.000797                             pre_time_group=='<20 Min'
# 3  0.000120  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 4  0.000007   difficulty=='pfiffig' AND pre_time_group=='<20 Min'
# ----------------------------------------------------------------------
# number of target combination is: 26
#     quality            ['weiblich', '45-60 Jahre', 'Verheiratet']
# 0  0.001945                           pre_time_group=='20-30 Min'
# 1  0.001209                             pre_time_group=='30+ Min'
# 2  0.001053  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 3  0.000915  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 4  0.000746                                 difficulty=='pfiffig'
# ----------------------------------------------------------------------
# number of target combination is: 27
#     quality              ['weiblich', '45-60 Jahre', 'Verwitwet']
# 0  0.000169                             pre_time_group=='<20 Min'
# 1  0.000146                                  difficulty=='simpel'
# 2  0.000137    difficulty=='simpel' AND pre_time_group=='<20 Min'
# 3  0.000034    difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.000009  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# ----------------------------------------------------------------------
# number of target combination is: 28
#     quality              ['weiblich', '60+ Jahre', 'Geschieden']
# 0  0.000019   difficulty=='normal' AND pre_time_group=='<20 Min'
# 1  0.000017                            pre_time_group=='<20 Min'
# 2  0.000016  difficulty=='pfiffig' AND pre_time_group=='30+ Min'
# 3  0.000014                                difficulty=='pfiffig'
# 4  0.000005                            pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 29
#     quality                   ['weiblich', '60+ Jahre', 'Single']
# 0  0.000190                             pre_time_group=='30+ Min'
# 1  0.000170                                  difficulty=='normal'
# 2  0.000156    difficulty=='normal' AND pre_time_group=='30+ Min'
# 3  0.000029  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 4  0.000020    difficulty=='simpel' AND pre_time_group=='30+ Min'
# ----------------------------------------------------------------------
# number of target combination is: 30
#     quality                 ['weiblich', '60+ Jahre', 'Vergeben']
# 0  0.000417                           pre_time_group=='20-30 Min'
# 1  0.000244  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.000179  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 3  0.000120                                  difficulty=='normal'
# 4  0.000054                                 difficulty=='pfiffig'
# ----------------------------------------------------------------------
# number of target combination is: 31
#     quality              ['weiblich', '60+ Jahre', 'Verheiratet']
# 0  0.000496                           pre_time_group=='20-30 Min'
# 1  0.000435  difficulty=='normal' AND pre_time_group=='20-30 Min'
# 2  0.000368                                  difficulty=='normal'
# 3  0.000196    difficulty=='normal' AND pre_time_group=='30+ Min'
# 4  0.000099  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# ----------------------------------------------------------------------
# number of target combination is: 32
#     quality                ['weiblich', '60+ Jahre', 'Verwitwet']
# 0  0.001352                                  difficulty=='simpel'
# 1  0.001268                             pre_time_group=='<20 Min'
# 2  0.001261    difficulty=='simpel' AND pre_time_group=='<20 Min'
# 3  0.000212  difficulty=='simpel' AND pre_time_group=='20-30 Min'
# 4  0.000030    difficulty=='normal' AND pre_time_group=='<20 Min'
# ----------------------------------------------------------------------
# number of target combination is: 33
#     quality                 ['weiblich', '<30 Jahre', 'Single']
# 0  0.000838                           pre_time_group=='<20 Min'
# 1  0.000712  difficulty=='simpel' AND pre_time_group=='<20 Min'
# 2  0.000334                                difficulty=='simpel'
# 3  0.000145  difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.000000                                             Dataset
# ----------------------------------------------------------------------
# number of target combination is: 34
#     quality               ['weiblich', '<30 Jahre', 'Vergeben']
# 0  0.001828                           pre_time_group=='<20 Min'
# 1  0.001290  difficulty=='simpel' AND pre_time_group=='<20 Min'
# 2  0.000627                                difficulty=='simpel'
# 3  0.000547  difficulty=='normal' AND pre_time_group=='<20 Min'
# 4  0.000000                                             Dataset
# ----------------------------------------------------------------------
# number of target combination is: 35
#     quality            ['weiblich', '<30 Jahre', 'Verheiratet']
# 0  0.000321                           pre_time_group=='30+ Min'
# 1  0.000272  difficulty=='normal' AND pre_time_group=='30+ Min'
# 2  0.000131  difficulty=='simpel' AND pre_time_group=='30+ Min'
# 3  0.000129                           pre_time_group=='<20 Min'
# 4  0.000112  difficulty=='normal' AND pre_time_group=='<20 Min'
# ----------------------------------------------------------------------
# number of target combination is: 36
#     quality                ['weiblich', '<30 Jahre', 'Verwitwet']
# 0  0.000013    difficulty=='normal' AND pre_time_group=='30+ Min'
# 1  0.000013                                  difficulty=='normal'
# 2  0.000011                             pre_time_group=='30+ Min'
# 3  0.000008                           pre_time_group=='20-30 Min'
# 4  0.000005  difficulty=='simpel' AND pre_time_group=='20-30 Min'

# %% [markdown]
# Conclusion:
#
# - 30-45 years-old female who are married likes "simple" or "pfiffig" food, which takes no more than 30 minuntes; 30-45 years-old female who are in relationship likes "simple" or "pfiffig" food, which takes more than 20 minuntes.
# - both married female or male who are in age groups '45-60' or '60 +' seem to prefer recipes that take more time (more than 20 minintes)
# - widowed female seems to prefer recipes which are simpler and take less time

# %% [markdown]
# - set target as subgroup, explore the tags of recipes, use multiclass-classifier

# %%
def get_distinct_tag(df):
    distinct_tags = []
    for i in range(len(df)):
        distinct_tags += df.iloc[i]['tags']
    return list(set(distinct_tags))

# %%
downsampled_new = downsampled_new.reset_index()
downsampled_new['tags'] = downsampled_new['tags'].astype(object)
for i in range(len(downsampled_new)):
    tags = downsampled_new.iloc[i]['tags']
    tags = tags_preprocess(tags)
    downsampled_new.at[i, 'tags'] = tags

# %%
# prepare the data for multiclass classifier
df = downsampled_new[['tags', 'sex', 'age_group', 'marriage_status', 'calorie_level']]
distinct_tags = get_distinct_tag(df)

# One hot encoding of the ingredients
df['tags'] = df.tags.apply(convert_to_dict)
vectorizer = DictVectorizer(sparse=False)
new_df = pd.DataFrame(data = vectorizer.fit_transform(df.tags.tolist()), columns = distinct_tags)
new_df[['sex', 'age_group', 'marriage_status', 'calorie_level']] = df[['sex', 'age_group', 'marriage_status', 'calorie_level']]

# set the target value by combining 'sex', 'age_group', 'marriage_status'
new_df['combine'] = new_df[['sex', 'age_group', 'marriage_status']].values.tolist()
new_df['combine'] = new_df['combine'].astype(str)
# Out:
# /Users/xujingjing/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# multiclass classifer
clf_X = new_df.iloc[:, :-5]
y = new_df.iloc[:, -1]

clf = LogisticRegression(max_iter=1000)
clf.fit(clf_X, y)
y_pred = clf.predict(clf_X)

# accuracy 
print("Accuracy:",clf.score(clf_X, y))
# Out:
# Accuracy: 0.2436802349236675

# %%
def computeIDF(clf_X):
    num_document = len(clf_X)
    idf_row = clf_X.sum(axis = 0, skipna = True) 
    idf_row = len(clf_X)/idf_row
    return idf_row

def computeTF(clf_X):
    clf_X['sum'] = clf_X.sum(axis = 1, skipna = True)
    clf_X = clf_X.div(clf_X['sum'], axis=0)
    clf_X = clf_X.drop(['sum'],axis = 1)
    return clf_X

# %%
# use td-idf to preprocess the data
idf_row = computeIDF(clf_X)
clf_X = computeTF(clf_X)
clf_X = clf_X*idf_row
clf_X = clf_X.fillna(0)
# Out:
# /Users/xujingjing/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# multiclass classifier after preprocessing with td-idf
clf = LogisticRegression(max_iter=1000)
clf.fit(clf_X, y)
y_pred = clf.predict(clf_X)

# accuracy 
print("Accuracy:",clf.score(clf_X, y))
# Out:
# Accuracy: 0.2428488032691185
# /Users/xujingjing/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
df = pd.DataFrame()
for i in range(len(clf.classes_)):
    if clf.classes_[i] != 'overlap':
        df[clf.classes_[i]] = [vectorizer.feature_names_[ing_id] for ing_id in np.argsort(-clf.coef_[i])[:10]]
df
# Out:
#   ['männlich', '30-45 Jahre', 'Geschieden']  \
# 0                                   spezial
# 1                                kartoffeln
# 2                          brotoderbrötchen
# 3                                   schweiz
# 4                                     suppe
# 5                                     paleo
# 6                                    mexiko
# 7                                    winter
# 8                                     party
# 9                                    kinder
#
#   ['männlich', '30-45 Jahre', 'Single']  \
# 0                         usaoderkanada
# 1                         meeresfrüchte
# 2                            frankreich
# 3                                  eier
# 4                                  wild
# 5                               amerika
# 6                                afrika
# 7                          eieroderkäse
# 8                              norwegen
# 9                                 pizza
#
#   ['männlich', '30-45 Jahre', 'Vergeben']  \
# 0                                  punsch
# 1                               silvester
# 2                            crosscooking
# 3                                  afrika
# 4                                russland
# 5                               römertopf
# 6                                  mexiko
# 7                           usaoderkanada
# 8                    gewürzeölessigpasten
# 9                                  ungarn
#
#   ['männlich', '30-45 Jahre', 'Verheiratet']  \
# 0                                     punsch
# 1                                 flambieren
# 2                               crosscooking
# 3                                    grillen
# 4                                    amerika
# 5                                 frittieren
# 6                              lateinamerika
# 7                               skandinavien
# 8                                   russland
# 9                                     kaffee
#
#   ['männlich', '45-60 Jahre', 'Geschieden']  \
# 0                                   fleisch
# 1                                   eintopf
# 2                                   marokko
# 3                                    kuchen
# 4                                frankreich
# 5                                      warm
# 6                    mittlererundnaherosten
# 7                                   früchte
# 8                                  einlagen
# 9                              geheimrezept
#
#   ['männlich', '45-60 Jahre', 'Single']  \
# 0                             innereien
# 1                   backenodersüßspeise
# 2                          eieroderkäse
# 3                               grillen
# 4                               vietnam
# 5                          weißrussland
# 6                                   wok
# 7                              norwegen
# 8                               dünsten
# 9                               wursten
#
#   ['männlich', '45-60 Jahre', 'Vergeben']  \
# 0                                    eier
# 1                                 wursten
# 2                                    klar
# 3                      kaffeeteeoderkakao
# 4                           usaoderkanada
# 5                                   pizza
# 6                                   korea
# 7                                 früchte
# 8                            wildgeflügel
# 9                              frankreich
#
#   ['männlich', '45-60 Jahre', 'Verheiratet']  \
# 0                                   portugal
# 1                                      china
# 2                               weißrussland
# 3                                       wild
# 4                                    wursten
# 5                                  römertopf
# 6                                   russland
# 7                                       kalt
# 8                                       klar
# 9                                blanchieren
#
#   ['männlich', '45-60 Jahre', 'Verwitwet']  \
# 0                                    pilze
# 1                                   braten
# 2                               fingerfood
# 3                                     klar
# 4                                    china
# 5                                       ei
# 6                             basisrezepte
# 7                                   kinder
# 8                          resteverwertung
# 9                                    party
#
#   ['männlich', '60+ Jahre', 'Geschieden']  ...  \
# 0                               aufstrich  ...
# 1                             babynahrung  ...
# 2                 raffiniertoderpreiswert  ...
# 3                          großbritannien  ...
# 4                            eieroderkäse  ...
# 5                                  europa  ...
# 6                                   fisch  ...
# 7                                      ei  ...
# 8                              überbacken  ...
# 9                                 fettarm  ...
#
#   ['weiblich', '45-60 Jahre', 'Verwitwet']  \
# 0                                   kuchen
# 1                          resteverwertung
# 2                                 schmoren
# 3                                trennkost
# 4                             crosscooking
# 5                               österreich
# 6                             reisgetreide
# 7                                   indien
# 8                               fingerfood
# 9                                   braten
#
#   ['weiblich', '60+ Jahre', 'Geschieden'] ['weiblich', '60+ Jahre', 'Single']  \
# 0                                  kuchen                              kuchen
# 1                                 eintopf                             belgien
# 2                             kalorienarm                            russland
# 3                                 marokko                        eieroderkäse
# 4                                    dips                         weihnachten
# 5                               osteuropa              mittlererundnaherosten
# 6                                  afrika                  ernährungskonzepte
# 7                           usaoderkanada                       haltbarmachen
# 8                                     wok                               creme
# 9                                  ostern                           südafrika
#
#   ['weiblich', '60+ Jahre', 'Vergeben']  \
# 0                             römertopf
# 1                              thailand
# 2                            flambieren
# 3               krustentierodermuscheln
# 4                            mikrowelle
# 5                             luxemburg
# 6                                 salat
# 7                          basisrezepte
# 8                              norwegen
# 9                        großbritannien
#
#   ['weiblich', '60+ Jahre', 'Verheiratet']  \
# 0                                    bowle
# 1                                longdrink
# 2                                    polen
# 3                            haltbarmachen
# 4                                 cocktail
# 5                     gewürzeölessigpasten
# 6                                 portugal
# 7                                  marokko
# 8                             grundrezepte
# 9                                     wild
#
#   ['weiblich', '60+ Jahre', 'Verwitwet'] ['weiblich', '<30 Jahre', 'Single']  \
# 0                          salatdressing                            dänemark
# 1                           griechenland                           longdrink
# 2                               einlagen                             getränk
# 3                                    tee                              nudeln
# 4                                 kaffee                           halloween
# 5                                  kakao                          mikrowelle
# 6                           grundrezepte                           osteuropa
# 7                            blanchieren                           südafrika
# 8                   gewürzeölessigpasten                  reisodernudelsalat
# 9                          meeresfrüchte                          diabetiker
#
#   ['weiblich', '<30 Jahre', 'Vergeben']  \
# 0                          weißrussland
# 1                                 japan
# 2                               marokko
# 3                  krustentieroderfisch
# 4                            konfiserie
# 5                                ungarn
# 6                                nudeln
# 7                                mexiko
# 8                        großbritannien
# 9                               vietnam
#
#   ['weiblich', '<30 Jahre', 'Verheiratet']  \
# 0                                 finnland
# 1                               australien
# 2                                 dänemark
# 3                   mittlererundnaherosten
# 4                             eieroderkäse
# 5                                   fondue
# 6                              mehlspeisen
# 7                         informempfehlung
# 8                       ernährungskonzepte
# 9                                  belgien
#
#   ['weiblich', '<30 Jahre', 'Verwitwet']
# 0                                beilage
# 1                                 gluten
# 2                                  vegan
# 3                                  tarte
# 4                               vollwert
# 5                            kalorienarm
# 6                                   warm
# 7                                fettarm
# 8                              vorspeise
# 9                                 sommer
#
# [10 rows x 36 columns]

# %%
the subgroup 30-45 years-old female who are married or in relationship seem to prefer the "high-calorie" recipes
the subgroup married 45-60 years-old male or the erdly who are married seem to prefer the "medium-calorie" recipes
the subgroup over 60 years old female or widowed female seem to prefer the "low-calorie" recipes

# %%
a_1 =['weiblich', '30-45 Jahre', 'Verheiratet']
a_1 = str(a_1)
a_2 = ['weiblich', '30-45 Jahre', 'Vergeben']
a_2 = str(a_2)
df[[a_1,a_2]]
# Out:
#   ['weiblich', '30-45 Jahre', 'Verheiratet']  \
# 0                               skandinavien
# 1                                babynahrung
# 2                                 konfiserie
# 3                                   russland
# 4                                 australien
# 5                                      torte
# 6                                     fondue
# 7                                niederlande
# 8                                   gebunden
# 9                                      polen
#
#   ['weiblich', '30-45 Jahre', 'Vergeben']
# 0                                  mexiko
# 1                           usaoderkanada
# 2                              konfiserie
# 3                                schweden
# 4                                   kekse
# 5                                dänemark
# 6                             babynahrung
# 7                            wildgeflügel
# 8                             niederlande
# 9                                   torte

# %%
b_1 = ['männlich', '45-60 Jahre', 'Verheiratet']
b_1 = str(b_1)
columns = list(df.columns)
cols_b = [l for l in columns if "Verheiratet" in l and "60+ Jahre" in l]
cols_b.append(b_1)
df[cols_b]
# Out:
#   ['männlich', '60+ Jahre', 'Verheiratet']  \
# 0                                  wursten
# 1                                  schweiz
# 2                                   punsch
# 3                            lammoderziege
# 4                                   fondue
# 5                      backenodersüßspeise
# 6                                osteuropa
# 7                                 festlich
# 8                                luxemburg
# 9                                silvester
#
#   ['weiblich', '60+ Jahre', 'Verheiratet']  \
# 0                                    bowle
# 1                                longdrink
# 2                                    polen
# 3                            haltbarmachen
# 4                                 cocktail
# 5                     gewürzeölessigpasten
# 6                                 portugal
# 7                                  marokko
# 8                             grundrezepte
# 9                                     wild
#
#   ['männlich', '45-60 Jahre', 'Verheiratet']
# 0                                   portugal
# 1                                      china
# 2                               weißrussland
# 3                                       wild
# 4                                    wursten
# 5                                  römertopf
# 6                                   russland
# 7                                       kalt
# 8                                       klar
# 9                                blanchieren

# %%
cols_c = [l for l in columns if "weiblich" in l and "60+ Jahre" in l]
cols_c += [l for l in columns if "weiblich" in l and "Verwitwet" in l]
df[cols_c]
# Out:
#   ['weiblich', '60+ Jahre', 'Geschieden'] ['weiblich', '60+ Jahre', 'Single']  \
# 0                                  kuchen                              kuchen
# 1                                 eintopf                             belgien
# 2                             kalorienarm                            russland
# 3                                 marokko                        eieroderkäse
# 4                                    dips                         weihnachten
# 5                               osteuropa              mittlererundnaherosten
# 6                                  afrika                  ernährungskonzepte
# 7                           usaoderkanada                       haltbarmachen
# 8                                     wok                               creme
# 9                                  ostern                           südafrika
#
#   ['weiblich', '60+ Jahre', 'Vergeben']  \
# 0                             römertopf
# 1                              thailand
# 2                            flambieren
# 3               krustentierodermuscheln
# 4                            mikrowelle
# 5                             luxemburg
# 6                                 salat
# 7                          basisrezepte
# 8                              norwegen
# 9                        großbritannien
#
#   ['weiblich', '60+ Jahre', 'Verheiratet']  \
# 0                                    bowle
# 1                                longdrink
# 2                                    polen
# 3                            haltbarmachen
# 4                                 cocktail
# 5                     gewürzeölessigpasten
# 6                                 portugal
# 7                                  marokko
# 8                             grundrezepte
# 9                                     wild
#
#   ['weiblich', '60+ Jahre', 'Verwitwet']  \
# 0                          salatdressing
# 1                           griechenland
# 2                               einlagen
# 3                                    tee
# 4                                 kaffee
# 5                                  kakao
# 6                           grundrezepte
# 7                            blanchieren
# 8                   gewürzeölessigpasten
# 9                          meeresfrüchte
#
#   ['weiblich', '30-45 Jahre', 'Verwitwet']  \
# 0                                    pilze
# 1                                  camping
# 2                                   nudeln
# 3                              deutschland
# 4                           studentenküche
# 5                                   braten
# 6                                   europa
# 7                                   gemüse
# 8                                  schnell
# 9                                  einfach
#
#   ['weiblich', '45-60 Jahre', 'Verwitwet']  \
# 0                                   kuchen
# 1                          resteverwertung
# 2                                 schmoren
# 3                                trennkost
# 4                             crosscooking
# 5                               österreich
# 6                             reisgetreide
# 7                                   indien
# 8                               fingerfood
# 9                                   braten
#
#   ['weiblich', '60+ Jahre', 'Verwitwet']  \
# 0                          salatdressing
# 1                           griechenland
# 2                               einlagen
# 3                                    tee
# 4                                 kaffee
# 5                                  kakao
# 6                           grundrezepte
# 7                            blanchieren
# 8                   gewürzeölessigpasten
# 9                          meeresfrüchte
#
#   ['weiblich', '<30 Jahre', 'Verwitwet']
# 0                                beilage
# 1                                 gluten
# 2                                  vegan
# 3                                  tarte
# 4                               vollwert
# 5                            kalorienarm
# 6                                   warm
# 7                                fettarm
# 8                              vorspeise
# 9                                 sommer

# %% [markdown]
# - set target as subgroup, explore the ingredients of recipes, use multiclass-classifier

# %%
# prepare the data for multi-class classifier
distinct_ingredients, df_2 = ingredients_preprocess(downsampled_new)

# One hot encoding of the ingredients
df_2['ingredient'] = df_2.ingredient.apply(convert_to_dict)
vectorizer = DictVectorizer(sparse=False)
new_df_2 = pd.DataFrame(data = vectorizer.fit_transform(df_2.ingredient.tolist()), columns = distinct_ingredients)
new_df_2[['sex', 'age_group', 'marriage_status', 'calorie_level']] = df_2[['sex', 'age_group', 'marriage_status', 'calorie_level']]

# set the target value by combining 'sex', 'age_group', 'marriage_status'
new_df_2['combine'] = new_df_2[['sex', 'age_group', 'marriage_status']].values.tolist()
new_df_2['combine'] = new_df_2['combine'].astype(str)

# %%
# multiclass classifer
clf_X = new_df_2.iloc[:, :-5]
y = new_df_2.iloc[:, -1]

clf = LogisticRegression(max_iter=1000)
clf.fit(clf_X, y)
y_pred = clf.predict(clf_X)

# accuracy 
print("Accuracy:",clf.score(clf_X, y))
# Out:
# Accuracy: 0.3580640025473651

# %%
df = pd.DataFrame()
for i in range(len(clf.classes_)):
    if clf.classes_[i] != 'overlap':
        df[clf.classes_[i]] = [vectorizer.feature_names_[ing_id] for ing_id in np.argsort(-clf.coef_[i])[:10]]
df
# Out:
#   ['männlich', '30-45 Jahre', 'Geschieden']  \
# 0                                kartoffeln
# 1                                  karotten
# 2                            bacongewürfelt
# 3                                     sesam
# 4                               tomatenmark
# 5                                  kasseler
# 6                                gemüsefond
# 7                                      hefe
# 8                      kartoffelngeviertelt
# 9                         rahmspinat1tkpack
#
#   ['männlich', '30-45 Jahre', 'Single']  \
# 0      speckinfeinenstreifenoderwürfeln
# 1                           schmelzkäse
# 2                       basilikumfrisch
# 3                             sauerteig
# 4                knoblauchfeingewürfelt
# 5                    butterfürdiepfanne
# 6                                safran
# 7        blattspinattkeinmalgrobgehackt
# 8     reisrisottoreisarborioodervialone
# 9                     rinderhackfleisch
#
#           ['männlich', '30-45 Jahre', 'Vergeben']  \
# 0  kartoffelnmöglichstgleichgroßeundmehligkochend
# 1                                 butterflöckchen
# 2                               schinkengekochter
# 3                               fettzumfrittieren
# 4                               oreganogetrocknet
# 5                                brüheklarinstant
# 6                         mehl405ambestenbackmehl
# 7          kartoffelnkleinefestkochendezbsiglinde
# 8                          kräuterlingezumstreuen
# 9                    frühstücksspeckfeingewürfelt
#
#   ['männlich', '30-45 Jahre', 'Verheiratet']  \
# 0                 schweinefleischlachsbraten
# 1             chiliflockenodercayennepfeffer
# 2                       bourbonvanillezucker
# 3                 paprikaschotenrotgewürfelt
# 4                             honigflüssigen
# 5                             lasagneplatten
# 6                                      rum54
# 7              karotteninscheibengeschnitten
# 8                               zwiebelnlila
# 9                                      kakao
#
#   ['männlich', '45-60 Jahre', 'Geschieden']  \
# 0                           sahnegeschlagen
# 1                           chilischotenrot
# 2                              schnittlauch
# 3                     vanilleschotendasmark
# 4                                    eigelb
# 5                kartoffelnmehligegeschälte
# 6                     apfelinkleinenstücken
# 7                       margarinereformhaus
# 8                                 senfsüßer
# 9                                      mett
#
#   ['männlich', '45-60 Jahre', 'Single']  \
# 0                                ingwer
# 1                      goudamittelalter
# 2                     toastbrotweißbrot
# 3                   saucenbinderbrauner
# 4                      majorangerebbelt
# 5                          tomatenfeste
# 6                             eieroder2
# 7                     lebernvomschweine
# 8                                  bier
# 9                               graupen
#
#                    ['männlich', '45-60 Jahre', 'Vergeben']  \
# 0                                                 brötchen
# 1                                             safranpulver
# 2                                backpulverodertrockenhefe
# 3                                             honigmelonen
# 4                                      eierleichtverquirlt
# 5                                                 sellerie
# 6  schinkenluftgetrocknetzbparmaersatzweisefrühstücksspeck
# 7                                        butterinflöckchen
# 8                                              tomaten400g
# 9                                 eiervomhuhnweißoderbraun
#
#   ['männlich', '45-60 Jahre', 'Verheiratet']  \
# 0                               speckmagerer
# 1                 schmalzzumfrittierenoderöl
# 2                             ingwerfrischer
# 3           mehlzumbestäubenderarbeitsfläche
# 4                            erdbeerenfrisch
# 5                                   handkäse
# 6                         himbeerengefrorene
# 7                              portweinroter
# 8                      steaksrindoderschwein
# 9         bandnudelnanderegehennatürlichauch
#
#   ['männlich', '45-60 Jahre', 'Verwitwet']  \
# 0                               petersilie
# 1                        chilisaucescharfe
# 2                         saucehoisinsauce
# 3                        ingwerfeingehackt
# 4                          sojasaucedunkle
# 5                knoblauchzehenfeingehackt
# 6                                   wasser
# 7                                    lauch
# 8                 champignonskleinefrische
# 9                  blattpetersiliegehackte
#
#        ['männlich', '60+ Jahre', 'Geschieden']  ...  \
# 0                                 gewürzgurken  ...
# 1                                  fischfilets  ...
# 2                                       muskat  ...
# 3                            frühlingszwiebeln  ...
# 4                                   mozzarella  ...
# 5                  kirschenevtlschwarzkirschen  ...
# 6            zuckeroderpuderzuckerzumbestäuben  ...
# 7  broterindetrockenevondunklembrotzerbröckelt  ...
# 8                           aromacitrobackevtl  ...
# 9            kondensmilchdosenmilchkaffeesahne  ...
#
#   ['weiblich', '45-60 Jahre', 'Verwitwet']  \
# 0                                  gewürze
# 1                                  wirsing
# 2                        haferflockenzarte
# 3                          zitronenpfeffer
# 4                              salatgurken
# 5                                  kräuter
# 6             brennnesselndiejungenblätter
# 7    chilischotengemahlenoderfrischgehackt
# 8                      ajvarscharfodermild
# 9       peperonimittelscharfvomtürkenladen
#
#       ['weiblich', '60+ Jahre', 'Geschieden']  \
# 0                                zitronensaft
# 1           puderzucker50gbuntezuckerstreusel
# 2                      joghurttürkischensüzme
# 3  hackfleischvomschweinambestenthüringermett
# 4                      knoblauchzehengeschält
# 5                        paprikapulveredelsüß
# 6                                 mehltype405
# 7                                 hefefrische
# 8                              knoblauchzehen
# 9                                  petersilie
#
#          ['weiblich', '60+ Jahre', 'Single']  \
# 0                                   portwein
# 1                                       mais
# 2               pfefferschwarzfrischgemahlen
# 3                           tomatengewürfelt
# 4                            lebkuchengewürz
# 5                   thunfischfiletausderdose
# 6                          kräuterquarkmager
# 7                     olivenölkaltgepresstes
# 8              trockenhefeoder30gfrischehefe
# 9  fetakäseoderanderenschafskäsenachbelieben
#
#   ['weiblich', '60+ Jahre', 'Vergeben']  \
# 0           milchziegenmindestens32fett
# 1                                 hirse
# 2                    essigweißweinessig
# 3  zitronenabgeriebeneschaleunbehandelt
# 4                      zwiebelnodermehr
# 5                              kohlrabi
# 6                            stärkemehl
# 7        rosenkohlfrischodertiefgekühlt
# 8              bierkannruhigeinpilssein
# 9                     salzleichtgehäuft
#
#   ['weiblich', '60+ Jahre', 'Verheiratet']  \
# 0                   zwetschgenoderpflaumen
# 1                      wasserkaltesoder1ei
# 2                              mangosreife
# 3                            stachelbeeren
# 4                             ananasfrisch
# 5                                remoulade
# 6                           currythaicurry
# 7                   paprikaschotengemischt
# 8                 orangendavon1unbehandelt
# 9       kondensmilchmilchmädchengezuckerte
#
#   ['weiblich', '60+ Jahre', 'Verwitwet']  \
# 0                    joghurtgriechischer
# 1                 thunfischineigenemsaft
# 2              kartoffelnkleinedrillinge
# 3             petersilieoderschnittlauch
# 4                        sardellenfilets
# 5                pellkartoffelnvomvortag
# 6                olivenschwarzeentsteint
# 7                           feigenfrisch
# 8                          pastanachwahl
# 9                          olivenölgutes
#
#                                         ['weiblich', '<30 Jahre', 'Single']  \
# 0                                                        schokoladenachwahl
# 1                                melonengaliamelonedasfruchtfleischabwiegen
# 2                                                    gnocchiausdemkühlregal
# 3  kräuterfrischenachbeliebenschnittlauchpetersiliekressedillliebstöckeletc
# 4                                                   naturjoghurtfettarm150g
# 5                                                          hokkaidokürbisse
# 6                                                              avocadosreif
# 7                                                             avocadosreife
# 8                                      schokoriegelsnickersschokonussriegel
# 9                            likörcappucinooptionaleisschmecktmitaberbesser
#
#   ['weiblich', '<30 Jahre', 'Vergeben']  \
# 0                           milch35fett
# 1                     eisvanilleeisevtl
# 2                        vanilleextrakt
# 3                                 kiwis
# 4                  naturjoghurt35oder15
# 5                     schokoladebittere
# 6             reisjasminoderbasmatireis
# 7              muskatnussfrischgerieben
# 8            buttervanillearomaoptional
# 9                        milchvollmilch
#
#     ['weiblich', '<30 Jahre', 'Verheiratet']  \
# 0  kartoffelnvorwiegendfestkochendodermehlig
# 1                           vanillegemahlene
# 2                                spekulatius
# 3                      mehlevtlmehrbiszu500g
# 4                              puddingpulver
# 5                                  honigoder
# 6                        champignonshalbiert
# 7                        kuvertürezartbitter
# 8                              tomatenkleine
# 9               farfalleschmetterlingsnudeln
#
#   ['weiblich', '<30 Jahre', 'Verwitwet']
# 0                        margarinevegane
# 1                     vollkornweizenmehl
# 2           salzgroboderfeinzumbestreuen
# 3                      wasserfürdielauge
# 4                     weizenmehlvollkorn
# 5                                 natron
# 6                               meersalz
# 7                             hefefrisch
# 8                          wasserlauwarm
# 9           grünkerndinkelgrobgeschrotet
#
# [10 rows x 36 columns]

# %%
a_1 =['weiblich', '30-45 Jahre', 'Verheiratet']
a_1 = str(a_1)
a_2 = ['weiblich', '30-45 Jahre', 'Vergeben']
a_2 = str(a_2)
df[[a_1,a_2]]
# Out:
#   ['weiblich', '30-45 Jahre', 'Verheiratet']  \
# 0                        fetakäsezerbröckelt
# 1               keksebutterkekse1dominostein
# 2                               erbsenfrisch
# 3                                butterwarme
# 4                       kräuternachgeschmack
# 5                 zitronenschaleunbehandelte
# 6                                 zuckerfein
# 7                       olivenölkaltgepresst
# 8                               saftkarotten
# 9                        haselnüssegemahlene
#
#               ['weiblich', '30-45 Jahre', 'Vergeben']
# 0                    salzundpfefferundknoblauchgewürz
# 1                     doppelrahmfrischkäsemitkräutern
# 2                                      maronengegarte
# 3  feldsalatalternativanderekleinblättrigesalatsorten
# 4                        tomatencocktailrispentomaten
# 5                     fetakäsegewürfeltinöleingelegte
# 6                                      kondensmilch10
# 7                                            reiswein
# 8                           puderzuckeroderzimtzucker
# 9        mandelmilchmandeldrinkalternativhafermilchoä

# %%
b_1 = ['männlich', '45-60 Jahre', 'Verheiratet']
b_1 = str(b_1)
columns = list(df.columns)
cols_b = [l for l in columns if "Verheiratet" in l and "60+ Jahre" in l]
cols_b.append(b_1)
df[cols_b]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-42d5d48305fa> in <module>
#       4 cols_b = [l for l in columns if "Verheiratet" in l and "60+ Jahre" in l]
#       5 cols_b.append(b_1)
# ----> 6 df[cols_b]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['['männlich', '45-60 Jahre', 'Verheiratet']'], dtype='object')] are in the [columns]"

# %%
cols_c = [l for l in columns if "weiblich" in l and "60+ Jahre" in l]
cols_c += [l for l in columns if "weiblich" in l and "Verwitwet" in l]
df[cols_c]
# Out:
#       ['weiblich', '60+ Jahre', 'Geschieden']  \
# 0                                zitronensaft
# 1           puderzucker50gbuntezuckerstreusel
# 2                      joghurttürkischensüzme
# 3  hackfleischvomschweinambestenthüringermett
# 4                      knoblauchzehengeschält
# 5                        paprikapulveredelsüß
# 6                                 mehltype405
# 7                                 hefefrische
# 8                              knoblauchzehen
# 9                                  petersilie
#
#          ['weiblich', '60+ Jahre', 'Single']  \
# 0                                   portwein
# 1                                       mais
# 2               pfefferschwarzfrischgemahlen
# 3                           tomatengewürfelt
# 4                            lebkuchengewürz
# 5                   thunfischfiletausderdose
# 6                          kräuterquarkmager
# 7                     olivenölkaltgepresstes
# 8              trockenhefeoder30gfrischehefe
# 9  fetakäseoderanderenschafskäsenachbelieben
#
#   ['weiblich', '60+ Jahre', 'Vergeben']  \
# 0           milchziegenmindestens32fett
# 1                                 hirse
# 2                    essigweißweinessig
# 3  zitronenabgeriebeneschaleunbehandelt
# 4                      zwiebelnodermehr
# 5                              kohlrabi
# 6                            stärkemehl
# 7        rosenkohlfrischodertiefgekühlt
# 8              bierkannruhigeinpilssein
# 9                     salzleichtgehäuft
#
#   ['weiblich', '60+ Jahre', 'Verheiratet']  \
# 0                   zwetschgenoderpflaumen
# 1                      wasserkaltesoder1ei
# 2                              mangosreife
# 3                            stachelbeeren
# 4                             ananasfrisch
# 5                                remoulade
# 6                           currythaicurry
# 7                   paprikaschotengemischt
# 8                 orangendavon1unbehandelt
# 9       kondensmilchmilchmädchengezuckerte
#
#   ['weiblich', '60+ Jahre', 'Verwitwet']  \
# 0                    joghurtgriechischer
# 1                 thunfischineigenemsaft
# 2              kartoffelnkleinedrillinge
# 3             petersilieoderschnittlauch
# 4                        sardellenfilets
# 5                pellkartoffelnvomvortag
# 6                olivenschwarzeentsteint
# 7                           feigenfrisch
# 8                          pastanachwahl
# 9                          olivenölgutes
#
#   ['weiblich', '30-45 Jahre', 'Verwitwet']  \
# 0                              maultaschen
# 1                  crèmefraîcheoderschmand
# 2                     salzundpfefferweißer
# 3                           paprikaschoten
# 4                       gemüsebrüheinstant
# 5                             schnittlauch
# 6                              champignons
# 7                                    lauch
# 8                                   wasser
# 9           semmelbröselodermehlfürdieform
#
#   ['weiblich', '45-60 Jahre', 'Verwitwet']  \
# 0                                  gewürze
# 1                                  wirsing
# 2                        haferflockenzarte
# 3                          zitronenpfeffer
# 4                              salatgurken
# 5                                  kräuter
# 6             brennnesselndiejungenblätter
# 7    chilischotengemahlenoderfrischgehackt
# 8                      ajvarscharfodermild
# 9       peperonimittelscharfvomtürkenladen
#
#   ['weiblich', '60+ Jahre', 'Verwitwet']  \
# 0                    joghurtgriechischer
# 1                 thunfischineigenemsaft
# 2              kartoffelnkleinedrillinge
# 3             petersilieoderschnittlauch
# 4                        sardellenfilets
# 5                pellkartoffelnvomvortag
# 6                olivenschwarzeentsteint
# 7                           feigenfrisch
# 8                          pastanachwahl
# 9                          olivenölgutes
#
#   ['weiblich', '<30 Jahre', 'Verwitwet']
# 0                        margarinevegane
# 1                     vollkornweizenmehl
# 2           salzgroboderfeinzumbestreuen
# 3                      wasserfürdielauge
# 4                     weizenmehlvollkorn
# 5                                 natron
# 6                               meersalz
# 7                             hefefrisch
# 8                          wasserlauwarm
# 9           grünkerndinkelgrobgeschrotet

# %% [markdown]
# - set target as calorie, explore the tags of recipes, use multiclass-classifier

# %%
# multiclass classifer
clf_X = new_df.iloc[:, :-5]
y = new_df.iloc[:, -2]

clf = LogisticRegression(max_iter=1000)
clf.fit(clf_X, y)
y_pred = clf.predict(clf_X)

# accuracy 
print("Accuracy:",clf.score(clf_X, y))
# Out:
# Accuracy: 0.6494011923083727

# %%
df = pd.DataFrame()
for i in range(len(clf.classes_)):
    if clf.classes_[i] != 'overlap':
        df[clf.classes_[i]] = [vectorizer.feature_names_[ing_id] for ing_id in np.argsort(-clf.coef_[i])[:10]]
df
# Out:
#                   high_calorie                   low_calorie  \
# 0                  ananasringe          apfelmusgehtauchohne
# 1    apfelmusevtlselbstgemacht            apfelmusausdemglas
# 2            ananasoderfrische            acetobalsamicohell
# 3                 ananasfrisch                apfelinstücken
# 4               aalegeräuchert                    amarettoca
# 5                   apfelca80g                  anisgemahlen
# 6                     apfelmus   acetobalsamicoacetodimodena
# 7                   anstellgut           ajvarscharfodermild
# 8                anissternanis               ananasinstücken
# 9  ajvarpaprikapasteausdemglas  ajvaroderpikantetomatensauce
#
#                    medium_calorie
# 0                     amarantpops
# 1         apfelessigoderweinessig
# 2         agavendicksaftoderhonig
# 3                    apfelgehackt
# 4                  ananassaftdose
# 5  apfelentkerntundkleingewürfelt
# 6       ananasinstückenausderdose
# 7                      anstellgut
# 8     acetobalsamicoacetodimodena
# 9                 ananasinstücken

# %% [markdown]
# ### Association rules among the recipe attributes

# %% [markdown]
# - the association with "ingredient" and "regions"

# %%
countries = ['china', 'indien', 'deutschland','frankreich','grossbritannien','österreich','usaoderkanada','italien','spanien',
             'portugal', 'japen','schweiz','türkei', 'thailand', 'russland', 'großbritannien & irland', 'vietnam', 'korea',
            'australien', 'ägypten', 'marokko', 'niederlande']

# %%
df_certain_countries = get_recipe_countries(countries, data)
df_certain_countries.reset_index(inplace = True)
df_certain_countries['label'].value_counts()

# %%
# drop all the columns other than "ingredient" and "label" column
columns_drop = ['index', 'categorize', 'recipe_name', 'tags', 'avg_score', 'difficulty','rating_count', 'calorie', 
                'preparation_time','comment_user', 'recipe_url']
df_certain_countries = df_certain_countries.drop(columns_drop, axis = 1)

# preprocess the ingredient column
distinct_ingredients = ingredients_preprocess(df_certain_countries)

# One hot encoding of the ingredients
df_certain_countries['ingredient'] = df_certain_countries.ingredient.apply(convert_to_dict)
vectorizer = DictVectorizer(sparse=False)
new_df_countries = pd.DataFrame(data = vectorizer.fit_transform(df_certain_countries.ingredient.tolist()), columns = distinct_ingredients)
new_df_countries['label'] = df_certain_countries.label

# dummy for the label column
new_df_countries = pd.get_dummies(new_df_countries)

# %%
# apply 
new_df_countries

# %%
test = new_df_countries.iloc[:,]
test = test.iloc[:4]

# %%
country_label = list(new_df_countries.iloc[:,-19:].columns)
#contry_label.remove('label_deutschland')

# record the start time
time1 = time.time()
        
# apply subgroup discovery 
target = ps.BinaryTarget ('label_usaoderkanada', True)
searchspace = ps.create_selectors(test, ignore = country_label)
task = ps.SubgroupDiscoveryTask (
    data, 
    target, 
    searchspace, 
    result_set_size=5, 
    depth=20, 
    qf=ps.WRAccQF())
result = ps.BeamSearch().execute(task)

# record the end time
time2 = time.time()
time_diff = (time2-time1)/60
print('it took ' + str(time_diff) + 'miniutes to execute the subgroup disc')
